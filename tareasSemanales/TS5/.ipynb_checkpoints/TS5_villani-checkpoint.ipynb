# %% [markdown]
# <img src="./src/LogoUTNNegro.png" align="right" width="150">
#
# #### Teoría de los Circuitos 2
#
# # Trabajo Semanal 5
# #### Renzo Villani

# %% [markdown]
# ### Consignas
#
# Dadas las siguientes topologías circuitales:
#
# <center><img src="./src/img1_TS5.jpeg"  width="800"></center>
#
# 1. Obtenga un solo juego de parámetros en forma analítica para cada caso:
#
# *Z, Y ó ABCD aplicando la definición:*
#
# <center><img src="./src/img2_TS5.png"  width="600"></center>
#
# 2. Aplicar transformación de parámetros para hallar los *Z, Y* si lo obtenido fue *ABCD* ó viceversa.
#
# Notas:
# - En las redes activas se cumple que $Z_{12} \neq Z_{21} \space\space\space;\space\space\space Y_{12} \neq Y_{21} \space\space\space;\space\space\space AD - BC \neq 1$
# - $Z_{11} = Z_{22} \space\space\space;\space\space\space Y_{11} = Y_{22} \space\space\space;\space\space\space A = D$
# - Puede que en algunos casos particulares el parámetro no tenga solución.
#
#
# **Bonus**
#
# +10 💎 Completar el siguiente cuestionario
#
# +10 💎 Simulación Circuital de alguna topología a elección y obtener el juego de parámetros , utilizando la directiva .NET , agregando las gráficas de los parámetros con *Add Traces*.
#
# +10 💎 Obtener el punto 1) para las siguientes redes.
#
# <center><img src="./src/img3_TS5.jpeg"  width="800"></center>

# %% [markdown]
# ###
# Puntos 1 y 2
#
# #### Red T
# Obtengo los parámetros Z por definición.
#
# <center><img src="./src/img4_TS5.png"  width="800"></center>
#
# Obtengo los parámetros T en función de los parámetros Z.
#
# <center><img src="./src/img5_TS5.png"  width="800"></center>
#
# Obtengo los parámetros Y en función de los parámetros Z.
#
# <center><img src="./src/img6_TS5.png"  width="800"></center>
#
#
# #### Red $\pi$
# Obtengo los parámetros Y por definición.
#
# <center><img src="./src/img7_TS5.png"  width="800"></center>
#
# Obtengo los parámetros T en función de los parámetros Y.
#
# <center><img src="./src/img8_TS5.png"  width="800"></center>
#
# Obtengo los parámetros Z en función de los parámetros Y.
#
# <center><img src="./src/img9_TS5.png"  width="800"></center>
#
#
# #### Lattice Simétrico
# Obtengo los parámetros T por definición.
# <center><img src="./src/img10_TS5.png"  width="800"></center>
# <center><img src="./src/img11_TS5.png"  width="800"></center>
#
# Obtengo los parámetros Z en función de los parámetros T.
#
# <center><img src="./src/img12_TS5.png"  width="800"></center>
#
# Obtengo los parámetros y en función de los parámetros T.
#
# <center><img src="./src/img13_TS5.png"  width="800"></center>

# %% [markdown]
# ### Bonus 3
#
# #### Transformador Ideal
#
# De por sí, las ecuaciones que rigen el comportamiento del cuadripolo son muy similares a las ecuaciones del modelo de parámetros T. Por tanto elijo obtener estos.
#
# <center><img src="./src/img14_TS5.png"  width="800"></center>
#
# #### Inversor
#
# Elijo obtener los parámetros Z de este cuadripolo. Hago provecho de la caractetística del opamp ideal de tener una impedancia de salida de 0 ($Z_{22}=0$).
#
# <center><img src="./src/img15_TS5.png"  width="800"></center>

# %% [markdown]
# ### Bonus 2
#
# Decidí simular la red $\pi$.
#
# <center><img src="./src/img16_TS5.jpeg"  width="800"></center>
# <center><img src="./src/img17_TS5.jpeg"  width="800"></center>
# <center><img src="./src/img18_TS5.jpeg"  width="800"></center>
#
#
# Resultados:
#
# - $Y_{11} = 1,5 s$
# - $Y_{12} = 0,5 s$
# - $Y_{21} = 0,5 s$
# - $Y_{22} = 0.83 s$
#
# - $Z_{11} = 0.83 \Omega$
# - $Z_{12} = 0.5 \Omega$
# - $Z_{21} = 0.5 \Omega$
# - $Z_{22} = 1.5 \Omega$
#
# Los resultados de la simulación coinciden con los valores esperados.

# %% [markdown]
# ### Conclusión
#
# En esta práctica se obtuvieron y analizaron los parámetros de dos puertos de distintas topologías circuitales, determinándolos tanto de forma analítica como mediante transformaciones entre representaciones Z, Y y ABCD. Los resultados obtenidos verificaron las relaciones teóricas entre los diferentes conjuntos de parámetros y permitieron identificar propiedades particulares de cada red, como simetría, reciprocidad y condiciones de existencia de ciertas representaciones.
#
# Además, la simulación circuital realizada mediante *LTspice* permitió corroborar los resultados analíticos, observándose una concordancia entre los parámetros calculados y los obtenidos numéricamente.
