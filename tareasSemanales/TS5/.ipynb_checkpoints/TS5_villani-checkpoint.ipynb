# %% [markdown]
# <img src="./src/LogoUTNNegro.png" align="right" width="150">
#
# #### Teoría de los Circuitos 2
#
# # Trabajo Semanal 5
# #### Renzo Villani

# %% [markdown]
# ### Consignas
#
# Dadas las siguientes topologías circuitales:
#
# <center><img src="./src/img1_TS5.jpeg"  width="800"></center>
#
# 1. Obtenga un solo juego de parámetros en forma analítica para cada caso:
#
# *Z, Y ó ABCD aplicando la definición:*
#
# <center><img src="./src/img2_TS5.png"  width="600"></center>
#
# 2. Aplicar transformación de parámetros para hallar los *Z, Y* si lo obtenido fue *ABCD* ó viceversa.
#
# Notas:
# - En las redes activas se cumple que $Z_{12} \neq Z_{21} \space\space\space;\space\space\space Y_{12} \neq Y_{21} \space\space\space;\space\space\space AD - BC \neq 1$
# - $Z_{11} = Z_{22} \space\space\space;\space\space\space Y_{11} = Y_{22} \space\space\space;\space\space\space A = D$
# - Puede que en algunos casos particulares el parámetro no tenga solución.
#
#
# **Bonus**
#
# +10 💎 Completar el siguiente cuestionario
#
# +10 💎 Simulación Circuital de alguna topología a elección y obtener el juego de parámetros , utilizando la directiva .NET , agregando las gráficas de los parámetros con *Add Traces*.
#
# +10 💎 Obtener el punto 1) para las siguientes redes.
#
# <center><img src="./src/img3_TS5.jpeg"  width="800"></center>

# %% [markdown]
# ### Punto 1

# %% [markdown]
# ### Punto 2

# %% [markdown]
# ### Bonus 1

# %% [markdown]
# ### Bonus 2

# %% [markdown]
# ### Bonus 3
